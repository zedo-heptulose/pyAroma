# %%
import sys
path1 = '/gpfs/home/gdb20/code/batch-manager/src/'
path2 = '/gpfs/home/gdb20/code/mol-maker/src/'
path3 = '/gpfs/home/gdb20/code/pyAroma/src/'
paths = [path1,path2,path3]
for path in paths:
    if path not in sys.path:
        sys.path.append(path)

# %%
import numpy as np
import os
import molecule as mol
import utilities as util
import mol_tree as mt 
import unitcell
import parse_tree
import file_parser
import postprocessing
import postprocessingDriver

# %%
root = '/gpfs/research/alabuginlab/gage/michael/test/benzene/'

# %%
sub_path_1 = 'cam-b3ylp_6-31Gdp_NICS_gaussian_test'
sub_path_2 = os.path.join(sub_path_1,sub_path_1) + '.log'

# %%
for i in range(3):
    for j in range(3):
        for k in range(3):
            mid_dir = f'_benzene_x{i}_y{j}_z{k}'
            path = os.path.join(root,mid_dir,sub_path_2)
            xyz_path = os.path.join(root,mid_dir,sub_path_1) + '/gaussian_prepro_test.xyz'
            mol.Molecule(filename=xyz_path).show()
            oa = postprocessingDriver.output_analyzer(path)
            for l in range (2):
                print(f'for {mid_dir}, {l}: {oa.computeNICSPerp(l,0)}')
            print(f'all isotropic shifts: {oa.allNICSIso}')
            print(f'all zz shifts: {oa.allNICSzz}')
            print(f'all perp shifts: {oa.allNICSPerp}')
            print(f'ring averaged perp: {oa.allNICSPerpAve}')
# Out:
# <div id="3dmolviewer_17330073935543647"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073935543647" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073935543647 = null;
# var warn = document.getElementById("3dmolwarning_17330073935543647");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073935543647 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073935543647"),{backgroundColor:"white"});
# viewer_17330073935543647.zoomTo();
# 	viewer_17330073935543647.addModel("14\n\nC 0.732760 1.179102 -0.000010\nC -0.654770 1.224126 -0.000010\nC -1.387510 0.045013 -0.000010\nC -0.732740 -1.179103 -0.000001\nC 0.654790 -1.224117 0.000009\nC 1.387530 -0.045014 -0.000001\nH 1.303919 2.098236 0.000098\nH -1.165278 2.178290 0.000025\nH -2.469084 0.080111 -0.000060\nH -1.303919 -2.098227 -0.000118\nH 1.165196 -2.178336 -0.000009\nH 2.469106 -0.080071 0.000067\nBq 0.000013 -0.000005 -1.000004\nBq 0.000007 0.000007 0.999996\n","xyz");
# 	viewer_17330073935543647.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073935543647.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073935543647.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935543647.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935543647.zoomTo();
# viewer_17330073935543647.render();
# });
# </script>
# angle between: 3.141592653589793
# ring normal: [ 3.17097310e-06 -5.92838106e-06 -1.00000000e+00]
# angle between: 3.141592653589793
# ring normal: [ 3.17097310e-06 -5.92838106e-06 -1.00000000e+00]
# angle between: 3.141592653589793
# ring normal: [ 3.17097310e-06 -5.92838106e-06 -1.00000000e+00]
# for _benzene_x0_y0_z0, 0: 29.759
# angle between: 3.141592653589793
# ring normal: [ 3.17097310e-06 -5.92838106e-06 -1.00000000e+00]
# for _benzene_x0_y0_z0, 1: 29.7592
# all isotropic shifts: [-11.498, -11.498]
# all zz shifts: [-29.759, -29.7592]
# all perp shifts: [np.float64(29.759), np.float64(29.7592)]
# ring averaged perp: [np.float64(29.7591)]
# <div id="3dmolviewer_17330073935677152"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073935677152" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073935677152 = null;
# var warn = document.getElementById("3dmolwarning_17330073935677152");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073935677152 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073935677152"),{backgroundColor:"white"});
# viewer_17330073935677152.zoomTo();
# 	viewer_17330073935677152.addModel("14\n\nC -0.596268 1.253667 -0.000010\nC -1.383840 0.110428 -0.000010\nC -0.787552 -1.143229 -0.000010\nC 0.596280 -1.253652 -0.000001\nC 1.383843 -0.110406 0.000009\nC 0.787564 1.143245 -0.000001\nH -1.061094 2.230891 0.000098\nH -2.462570 0.196388 0.000025\nH -1.401462 -2.034378 -0.000060\nH 1.061086 -2.230887 -0.000118\nH 2.462565 -0.196481 -0.000009\nH 1.401441 2.034418 0.000067\nBq 0.000011 0.000008 -1.000004\nBq -0.000002 0.000009 0.999996\n","xyz");
# 	viewer_17330073935677152.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073935677152.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073935677152.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935677152.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935677152.zoomTo();
# viewer_17330073935677152.render();
# });
# </script>
# angle between: 3.141592653589793
# ring normal: [ 6.70184533e-06 -5.34836163e-07 -1.00000000e+00]
# angle between: 3.141592653589793
# ring normal: [ 6.70184533e-06 -5.34836163e-07 -1.00000000e+00]
# angle between: 3.141592653589793
# ring normal: [ 6.70184533e-06 -5.34836163e-07 -1.00000000e+00]
# for _benzene_x0_y0_z1, 0: 29.7566
# angle between: 3.141592653589793
# ring normal: [ 6.70184533e-06 -5.34836163e-07 -1.00000000e+00]
# for _benzene_x0_y0_z1, 1: 29.7568
# all isotropic shifts: [-11.4967, -11.4968]
# all zz shifts: [-29.7566, -29.7568]
# all perp shifts: [np.float64(29.7566), np.float64(29.7568)]
# ring averaged perp: [np.float64(29.7567)]
# <div id="3dmolviewer_17330073935760126"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073935760126" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073935760126 = null;
# var warn = document.getElementById("3dmolwarning_17330073935760126");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073935760126 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073935760126"),{backgroundColor:"white"});
# viewer_17330073935760126.zoomTo();
# 	viewer_17330073935760126.addModel("14\n\nC -1.377090 0.175617 -0.000010\nC -0.840614 -1.104796 -0.000010\nC 0.536478 -1.280391 -0.000010\nC 1.377083 -0.175599 -0.000001\nC 0.840597 1.104811 0.000009\nC -0.536485 1.280410 -0.000001\nH -2.450542 0.312476 0.000098\nH -1.495787 -1.966073 0.000025\nH 0.954657 -2.278469 -0.000060\nH 2.450534 -0.312480 -0.000118\nH 1.495863 1.966018 -0.000009\nH -0.954702 2.278473 0.000067\nBq -0.000001 0.000014 -1.000004\nBq -0.000009 0.000003 0.999996\n","xyz");
# 	viewer_17330073935760126.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073935760126.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073935760126.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935760126.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935760126.zoomTo();
# viewer_17330073935760126.render();
# });
# </script>
# angle between: 3.141592653589793
# ring normal: [ 4.07107200e-06  5.35043722e-06 -1.00000000e+00]
# angle between: 3.141592653589793
# ring normal: [ 4.07107200e-06  5.35043722e-06 -1.00000000e+00]
# angle between: 3.141592653589793
# ring normal: [ 4.07107200e-06  5.35043722e-06 -1.00000000e+00]
# for _benzene_x0_y0_z2, 0: 29.7553
# angle between: 3.141592653589793
# ring normal: [ 4.07107200e-06  5.35043722e-06 -1.00000000e+00]
# for _benzene_x0_y0_z2, 1: 29.7555
# all isotropic shifts: [-11.4961, -11.4962]
# all zz shifts: [-29.7553, -29.7555]
# all perp shifts: [np.float64(29.7553), np.float64(29.7555)]
# ring averaged perp: [np.float64(29.7554)]
# <div id="3dmolviewer_17330073935830836"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073935830836" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073935830836 = null;
# var warn = document.getElementById("3dmolwarning_17330073935830836");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073935830836 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073935830836"),{backgroundColor:"white"});
# viewer_17330073935830836.zoomTo();
# 	viewer_17330073935830836.addModel("14\n\nC 0.395903 1.179102 -0.616602\nC -0.353782 1.224126 0.550964\nC -0.749684 0.045013 1.167544\nC -0.395902 -1.179103 0.616579\nC 0.353792 -1.224117 -0.550982\nC 0.749685 -0.045014 -1.167566\nH 0.704592 2.098236 -1.097157\nH -0.629581 2.178290 0.980561\nH -1.334102 0.080111 2.077630\nH -0.704610 -2.098227 1.097146\nH 0.629551 -2.178336 -0.980484\nH 1.334120 -0.080071 -2.077644\nBq 0.841471 0.000007 0.540295\nBq -0.841467 -0.000005 -0.540316\n","xyz");
# 	viewer_17330073935830836.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073935830836.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073935830836.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935830836.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935830836.zoomTo();
# viewer_17330073935830836.render();
# });
# </script>
# angle between: -2.1415960368050437
# ring normal: [-8.41469157e-01 -6.06646354e-06 -5.40305153e-01]
# angle between: -2.1415960368050437
# ring normal: [-8.41469157e-01 -6.06646354e-06 -5.40305153e-01]
# angle between: -2.1415960368050437
# ring normal: [-8.41469157e-01 -6.06646354e-06 -5.40305153e-01]
# for _benzene_x0_y1_z0, 0: -4.880006914625581
# angle between: -2.1415960368050437
# ring normal: [-8.41469157e-01 -6.06646354e-06 -5.40305153e-01]
# for _benzene_x0_y1_z0, 1: -4.879802300894975
# all isotropic shifts: [-11.498, -11.4979]
# all zz shifts: [-10.3648, -10.3644]
# all perp shifts: [np.float64(-4.880006914625581), np.float64(-4.879802300894975)]
# ring averaged perp: [np.float64(-4.879904607760278)]
# <div id="3dmolviewer_17330073935946212"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073935946212" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073935946212 = null;
# var warn = document.getElementById("3dmolwarning_17330073935946212");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073935946212 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073935946212"),{backgroundColor:"white"});
# viewer_17330073935946212.zoomTo();
# 	viewer_17330073935946212.addModel("14\n\nC -0.778272 0.970212 -0.616602\nC -1.221216 0.363701 0.550964\nC -0.442933 -0.606516 1.167544\nC 0.778274 -0.970212 0.616579\nC 1.221213 -0.363687 -0.550982\nC 0.442935 0.606517 -1.167566\nH -1.384912 1.726576 -1.097157\nH -2.173132 0.647161 0.980561\nH -0.788229 -1.079324 2.077630\nH 1.384895 -1.726586 1.097146\nH 2.173154 -0.647211 -0.980484\nH 0.788206 1.079361 -2.077644\nBq 0.454643 0.708078 0.540295\nBq -0.454642 -0.708073 -0.540316\n","xyz");
# 	viewer_17330073935946212.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073935946212.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073935946212.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935946212.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073935946212.zoomTo();
# viewer_17330073935946212.render();
# });
# </script>
# angle between: -2.1415959778673943
# ring normal: [-0.45464264 -0.70807519 -0.5403051 ]
# angle between: -2.1415959778673943
# ring normal: [-0.45464264 -0.70807519 -0.5403051 ]
# angle between: -2.1415959778673943
# ring normal: [-0.45464264 -0.70807519 -0.5403051 ]
# for _benzene_x0_y1_z1, 0: -4.879082858589923
# angle between: -2.1415959778673943
# ring normal: [-0.45464264 -0.70807519 -0.5403051 ]
# for _benzene_x0_y1_z1, 1: -4.878791773239132
# all isotropic shifts: [-11.4964, -11.4963]
# all zz shifts: [-10.3617, -10.3612]
# all perp shifts: [np.float64(-4.879082858589923), np.float64(-4.878791773239132)]
# ring averaged perp: [np.float64(-4.878937315914527)]
# <div id="3dmolviewer_173300739360371"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_173300739360371" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_173300739360371 = null;
# var warn = document.getElementById("3dmolwarning_173300739360371");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_173300739360371 = $3Dmol.createViewer(document.getElementById("3dmolviewer_173300739360371"),{backgroundColor:"white"});
# viewer_173300739360371.zoomTo();
# 	viewer_173300739360371.addModel("14\n\nC -1.236908 -0.130686 -0.616602\nC -0.965869 -0.831109 0.550964\nC 0.271048 -0.700417 1.167544\nC 1.236909 0.130688 0.616579\nC 0.965857 0.831114 -0.550982\nC -0.271048 0.700419 -1.167566\nH -2.201134 -0.232490 -1.097157\nH -1.718715 -1.478965 0.980561\nH 0.482338 -1.246433 2.077630\nH 2.201133 0.232470 1.097146\nH 1.718770 1.478956 -0.980484\nH -0.482382 1.246433 -2.077644\nBq 0.350178 -0.765142 -0.540315\nBq -0.350182 0.765145 0.540294\n","xyz");
# 	viewer_173300739360371.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_173300739360371.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_173300739360371.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_173300739360371.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_173300739360371.zoomTo();
# viewer_173300739360371.render();
# });
# </script>
# angle between: -2.1415957395658958
# ring normal: [ 0.35018031 -0.76514336 -0.5403049 ]
# angle between: -2.1415957395658958
# ring normal: [ 0.35018031 -0.76514336 -0.5403049 ]
# angle between: -2.1415957395658958
# ring normal: [ 0.35018031 -0.76514336 -0.5403049 ]
# for _benzene_x0_y1_z2, 0: -4.8808126768805575
# angle between: -2.1415957395658958
# ring normal: [ 0.35018031 -0.76514336 -0.5403049 ]
# for _benzene_x0_y1_z2, 1: -4.88103015020233
# all isotropic shifts: [-11.4978, -11.4978]
# all zz shifts: [-10.364, -10.3645]
# all perp shifts: [np.float64(-4.8808126768805575), np.float64(-4.88103015020233)]
# ring averaged perp: [np.float64(-4.880921413541444)]
# <div id="3dmolviewer_17330073936122684"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073936122684" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073936122684 = null;
# var warn = document.getElementById("3dmolwarning_17330073936122684");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073936122684 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073936122684"),{backgroundColor:"white"});
# viewer_17330073936122684.zoomTo();
# 	viewer_17330073936122684.addModel("14\n\nC -0.304945 1.179102 -0.666292\nC 0.272471 1.224126 0.595385\nC 0.577399 0.045013 1.261664\nC 0.304927 -1.179103 0.666279\nC -0.272481 -1.224117 -0.595403\nC -0.577417 -0.045014 -1.261677\nH -0.542533 2.098236 -1.185691\nH 0.484950 2.178290 1.059574\nH 1.027447 0.080111 2.245156\nH 0.542514 -2.098227 1.185700\nH -0.484901 -2.178336 -1.059506\nH -1.027449 -0.080071 -2.245179\nBq 0.909291 0.000007 -0.416151\nBq -0.909306 -0.000005 0.416137\n","xyz");
# 	viewer_17330073936122684.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073936122684.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073936122684.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936122684.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936122684.zoomTo();
# viewer_17330073936122684.render();
# });
# </script>
# angle between: -1.9999968734293352
# ring normal: [ 9.09298728e-01  6.14373709e-06 -4.16143994e-01]
# angle between: -1.9999968734293352
# ring normal: [ 9.09298728e-01  6.14373709e-06 -4.16143994e-01]
# angle between: -1.9999968734293352
# ring normal: [ 9.09298728e-01  6.14373709e-06 -4.16143994e-01]
# for _benzene_x0_y2_z0, 0: -6.46560895789973
# angle between: -1.9999968734293352
# ring normal: [ 9.09298728e-01  6.14373709e-06 -4.16143994e-01]
# for _benzene_x0_y2_z0, 1: -6.4659387646799935
# all isotropic shifts: [-11.4964, -11.4963]
# all zz shifts: [-7.1103, -7.1106]
# all perp shifts: [np.float64(-6.46560895789973), np.float64(-6.4659387646799935)]
# ring averaged perp: [np.float64(-6.465773861289861)]
# <div id="3dmolviewer_17330073936200707"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073936200707" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073936200707 = null;
# var warn = document.getElementById("3dmolwarning_17330073936200707");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073936200707 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073936200707"),{backgroundColor:"white"});
# viewer_17330073936200707.zoomTo();
# 	viewer_17330073936200707.addModel("14\n\nC -1.156942 0.380469 -0.666292\nC -0.882850 0.890674 0.595385\nC 0.274093 0.510185 1.261664\nC 1.156934 -0.380485 0.666279\nC 0.882837 -0.890678 -0.595403\nC -0.274101 -0.510201 -1.261677\nH -2.058736 0.677156 -1.185691\nH -1.570949 1.585006 1.059574\nH 0.487721 0.907850 2.245156\nH 2.058719 -0.677167 1.185700\nH 1.571013 -1.584990 -1.059506\nH -0.487756 -0.907831 -2.245179\nBq 0.491286 0.765146 -0.416151\nBq -0.491296 -0.765158 0.416137\n","xyz");
# 	viewer_17330073936200707.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073936200707.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073936200707.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936200707.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936200707.zoomTo();
# viewer_17330073936200707.render();
# });
# </script>
# angle between: -1.9999967110142458
# ring normal: [ 0.49129097  0.76515193 -0.41614385]
# angle between: -1.9999967110142458
# ring normal: [ 0.49129097  0.76515193 -0.41614385]
# angle between: -1.9999967110142458
# ring normal: [ 0.49129097  0.76515193 -0.41614385]
# for _benzene_x0_y2_z1, 0: -6.463483737432376
# angle between: -1.9999967110142458
# ring normal: [ 0.49129097  0.76515193 -0.41614385]
# for _benzene_x0_y2_z1, 1: -6.463839728439421
# all isotropic shifts: [-11.4959, -11.4958]
# all zz shifts: [-7.1089, -7.1092]
# all perp shifts: [np.float64(-6.463483737432376), np.float64(-6.463839728439421)]
# ring averaged perp: [np.float64(-6.463661732935899)]
# <div id="3dmolviewer_17330073936272168"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073936272168" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073936272168 = null;
# var warn = document.getElementById("3dmolwarning_17330073936272168");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073936272168 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073936272168"),{backgroundColor:"white"});
# viewer_17330073936272168.zoomTo();
# 	viewer_17330073936272168.addModel("14\n\nC -0.945252 -0.767965 -0.666292\nC -1.226482 -0.261659 0.595385\nC -0.281213 0.506295 1.261664\nC 0.945261 0.767949 0.666279\nC 1.226478 0.261646 -0.595403\nC 0.281221 -0.506311 -1.261677\nH -1.682147 -1.366498 -1.185691\nH -2.182524 -0.465525 1.059574\nH -0.500413 0.900917 2.245156\nH 1.682147 1.366477 1.185700\nH 2.182545 0.465588 -1.059506\nH 0.500378 -0.900936 -2.245179\nBq 0.378410 -0.826828 0.416136\nBq -0.378405 0.826813 -0.416151\n","xyz");
# 	viewer_17330073936272168.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073936272168.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073936272168.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936272168.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936272168.zoomTo();
# viewer_17330073936272168.render();
# });
# </script>
# angle between: -1.9999966134640326
# ring normal: [-0.37840743  0.82682053 -0.41614376]
# angle between: -1.9999966134640326
# ring normal: [-0.37840743  0.82682053 -0.41614376]
# angle between: -1.9999966134640326
# ring normal: [-0.37840743  0.82682053 -0.41614376]
# for _benzene_x0_y2_z2, 0: -6.465649544537214
# angle between: -1.9999966134640326
# ring normal: [-0.37840743  0.82682053 -0.41614376]
# for _benzene_x0_y2_z2, 1: -6.465330137223431
# all isotropic shifts: [-11.4955, -11.4955]
# all zz shifts: [-7.1097, -7.1094]
# all perp shifts: [np.float64(-6.465649544537214), np.float64(-6.465330137223431)]
# ring averaged perp: [np.float64(-6.4654898408803225)]
# <div id="3dmolviewer_17330073936344583"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073936344583" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073936344583 = null;
# var warn = document.getElementById("3dmolwarning_17330073936344583");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073936344583 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073936344583"),{backgroundColor:"white"});
# viewer_17330073936344583.zoomTo();
# 	viewer_17330073936344583.addModel("14\n\nC 0.732760 0.637080 0.992174\nC -0.654770 0.661407 1.030061\nC -1.387510 0.024329 0.037872\nC -0.732740 -0.637072 -0.992181\nC 0.654790 -0.661401 -1.030054\nC 1.387530 -0.024321 -0.037879\nH 1.303919 1.133599 1.765657\nH -1.165278 1.176914 1.832981\nH -2.469084 0.043335 0.067378\nH -1.303919 -1.133577 -1.765661\nH 1.165196 -1.176952 -1.833012\nH 2.469106 -0.043319 -0.067341\nBq 0.000013 0.841471 -0.540309\nBq 0.000007 -0.841464 0.540306\n","xyz");
# 	viewer_17330073936344583.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073936344583.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073936344583.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936344583.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073936344583.zoomTo();
# viewer_17330073936344583.render();
# });
# </script>
# angle between: -2.1415990004273793
# ring normal: [ 3.10411303e-06  8.41467556e-01 -5.40307647e-01]
# angle between: -2.1415990004273793
# ring normal: [ 3.10411303e-06  8.41467556e-01 -5.40307647e-01]
# angle between: -2.1415990004273793
# ring normal: [ 3.10411303e-06  8.41467556e-01 -5.40307647e-01]
# for _benzene_x1_y0_z0, 0: -4.880446509305553
# angle between: -2.1415990004273793
# ring normal: [ 3.10411303e-06  8.41467556e-01 -5.40307647e-01]
# for _benzene_x1_y0_z0, 1: -4.880476625917279
# all isotropic shifts: [-11.496, -11.4961]
# all zz shifts: [-10.3625, -10.3626]
# all perp shifts: [np.float64(-4.880446509305553), np.float64(-4.880476625917279)]
# ring averaged perp: [np.float64(-4.880461567611416)]
# <div id="3dmolviewer_173300739364181"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_173300739364181" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_173300739364181 = null;
# var warn = document.getElementById("3dmolwarning_173300739364181");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_173300739364181 = $3Dmol.createViewer(document.getElementById("3dmolviewer_173300739364181"),{backgroundColor:"white"});
# viewer_173300739364181.zoomTo();
# 	viewer_173300739364181.addModel("14\n\nC -0.140173 0.960812 0.992174\nC -0.910328 -0.193610 1.030061\nC -0.770147 -1.154404 0.037872\nC 0.140176 -0.960791 -0.992181\nC 0.910334 0.193630 -1.030054\nC 0.770151 1.154425 -0.037879\nH -0.249381 1.709696 1.765657\nH -1.619941 -0.344658 1.832981\nH -1.370516 -2.054248 0.067378\nH 0.249362 -1.709685 -1.765661\nH 1.619929 0.344569 -1.833012\nH 1.370515 2.054275 -0.067341\nBq 0.708071 -0.454639 0.540306\nBq -0.708067 0.454660 -0.540309\n","xyz");
# 	viewer_173300739364181.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_173300739364181.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_173300739364181.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_173300739364181.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_173300739364181.zoomTo();
# viewer_173300739364181.render();
# });
# </script>
# angle between: -2.1415989426133404
# ring normal: [-0.70806886  0.45464952 -0.5403076 ]
# angle between: -2.1415989426133404
# ring normal: [-0.70806886  0.45464952 -0.5403076 ]
# angle between: -2.1415989426133404
# ring normal: [-0.70806886  0.45464952 -0.5403076 ]
# for _benzene_x1_y0_z1, 0: -4.878172119135865
# angle between: -2.1415989426133404
# ring normal: [-0.70806886  0.45464952 -0.5403076 ]
# for _benzene_x1_y0_z1, 1: -4.878135219990891
# all isotropic shifts: [-11.4964, -11.4963]
# all zz shifts: [-10.362, -10.3619]
# all perp shifts: [np.float64(-4.878172119135865), np.float64(-4.878135219990891)]
# ring averaged perp: [np.float64(-4.878153669563378)]
# <div id="3dmolviewer_17330073936491275"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073936491275" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
# ...
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073937387927 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073937387927"),{backgroundColor:"white"});
# viewer_17330073937387927.zoomTo();
# 	viewer_17330073937387927.addModel("14\n\nC -0.094036 1.384552 -0.037306\nC 0.220644 0.741987 1.152379\nC 0.314665 -0.642565 1.189667\nC 0.094021 -1.384544 0.037292\nC -0.220649 -0.741969 -1.152392\nC -0.314680 0.642573 -1.189681\nH -0.167217 2.463824 -0.066378\nH 0.392702 1.320276 2.050726\nH 0.559908 -1.143443 2.117034\nH 0.167197 -2.463818 0.066387\nH -0.392671 -1.320355 -2.050684\nH -0.559904 1.143489 -2.117034\nBq 0.972542 0.059997 -0.224846\nBq -0.972553 -0.059986 0.224832\n","xyz");
# 	viewer_17330073937387927.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073937387927.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073937387927.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937387927.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937387927.zoomTo();
# viewer_17330073937387927.render();
# });
# </script>
# angle between: -1.7975743247820397
# ring normal: [ 0.97254737  0.05999134 -0.22483919]
# angle between: -1.7975743247820397
# ring normal: [ 0.97254737  0.05999134 -0.22483919]
# angle between: -1.7975743247820397
# ring normal: [ 0.97254737  0.05999134 -0.22483919]
# for _benzene_x2_y1_z2, 0: -5.002501194712195
# angle between: -1.7975743247820397
# ring normal: [ 0.97254737  0.05999134 -0.22483919]
# for _benzene_x2_y1_z2, 1: -5.003068238346237
# all isotropic shifts: [-11.4972, -11.4971]
# all zz shifts: [-3.7514, -3.7515]
# all perp shifts: [np.float64(-5.002501194712195), np.float64(-5.003068238346237)]
# ring averaged perp: [np.float64(-5.0027847165292165)]
# <div id="3dmolviewer_17330073937463782"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073937463782" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073937463782 = null;
# var warn = document.getElementById("3dmolwarning_17330073937463782");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073937463782 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073937463782"),{backgroundColor:"white"});
# viewer_17330073937463782.zoomTo();
# 	viewer_17330073937463782.addModel("14\n\nC 0.669975 -0.490670 -1.112472\nC 1.284618 -0.509407 0.132168\nC 0.614630 -0.018723 1.244625\nC -0.669980 0.490680 1.112453\nC -1.284619 0.509404 -0.132190\nC -0.614635 0.018733 -1.244644\nH 1.192208 -0.873263 -1.979608\nH 2.285975 -0.906511 0.235321\nH 1.093761 -0.033283 2.214807\nH -1.192193 0.873278 1.979602\nH -2.285985 0.906516 -0.235227\nH -1.093740 0.033260 -2.214841\nBq 0.378393 0.909303 -0.173189\nBq -0.378397 -0.909297 0.173169\n","xyz");
# 	viewer_17330073937463782.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073937463782.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073937463782.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937463782.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937463782.zoomTo();
# viewer_17330073937463782.render();
# });
# </script>
# angle between: -1.744852620053015
# ring normal: [ 0.37839478  0.90930001 -0.17317877]
# angle between: -1.744852620053015
# ring normal: [ 0.37839478  0.90930001 -0.17317877]
# angle between: -1.744852620053015
# ring normal: [ 0.37839478  0.90930001 -0.17317877]
# for _benzene_x2_y2_z0, 0: -4.049168377598187
# angle between: -1.744852620053015
# ring normal: [ 0.37839478  0.90930001 -0.17317877]
# for _benzene_x2_y2_z0, 1: -4.049880566560161
# all isotropic shifts: [-11.4985, -11.4986]
# all zz shifts: [-3.1895, -3.1895]
# all perp shifts: [np.float64(-4.049168377598187), np.float64(-4.049880566560161)]
# ring averaged perp: [np.float64(-4.049524472079174)]
# <div id="3dmolviewer_17330073937538023"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073937538023" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073937538023 = null;
# var warn = document.getElementById("3dmolwarning_17330073937538023");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073937538023 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073937538023"),{backgroundColor:"white"});
# viewer_17330073937538023.zoomTo();
# 	viewer_17330073937538023.addModel("14\n\nC 0.774874 0.298654 -1.112472\nC 1.122733 0.805735 0.132168\nC 0.347840 0.507077 1.244625\nC -0.774885 -0.298653 1.112453\nC -1.122731 -0.805737 -0.132190\nC -0.347852 -0.507076 -1.244644\nH 1.378978 0.531383 -1.979608\nH 1.997921 1.433791 0.235321\nH 0.618968 0.902385 2.214807\nH -1.378983 -0.531362 1.979602\nH -1.997930 -1.433797 -0.235227\nH -0.618938 -0.902380 -2.214841\nBq 0.560698 -0.809705 0.173169\nBq -0.560705 0.809705 -0.173189\n","xyz");
# 	viewer_17330073937538023.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073937538023.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073937538023.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937538023.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937538023.zoomTo();
# viewer_17330073937538023.render();
# });
# </script>
# angle between: -1.7448528423143794
# ring normal: [-0.5607019   0.80970515 -0.17317899]
# angle between: -1.7448528423143794
# ring normal: [-0.5607019   0.80970515 -0.17317899]
# angle between: -1.7448528423143794
# ring normal: [-0.5607019   0.80970515 -0.17317899]
# for _benzene_x2_y2_z1, 0: -4.050420693934634
# angle between: -1.7448528423143794
# ring normal: [-0.5607019   0.80970515 -0.17317899]
# for _benzene_x2_y2_z1, 1: -4.049735490414046
# all isotropic shifts: [-11.498, -11.498]
# all zz shifts: [-3.1893, -3.1893]
# all perp shifts: [np.float64(-4.050420693934634), np.float64(-4.049735490414046)]
# ring averaged perp: [np.float64(-4.05007809217434)]
# <div id="3dmolviewer_17330073937614915"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17330073937614915" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.0/3Dmol-min.js');
# }
#
# var viewer_17330073937614915 = null;
# var warn = document.getElementById("3dmolwarning_17330073937614915");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17330073937614915 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17330073937614915"),{backgroundColor:"white"});
# viewer_17330073937614915.zoomTo();
# 	viewer_17330073937614915.addModel("14\n\nC 0.167357 0.813397 -1.112472\nC -0.071388 1.380088 0.132168\nC -0.238752 0.566672 1.244625\nC -0.167364 -0.813407 1.112453\nC 0.071390 -1.380087 -0.132190\nC 0.238744 -0.566681 -1.244644\nH 0.297922 1.447478 -1.979608\nH -0.127013 2.455873 0.235321\nH -0.424901 1.008405 2.214807\nH -0.297942 -1.447470 1.979602\nH 0.127013 -2.455884 -0.235227\nH 0.424913 -1.008376 -2.214841\nBq 0.984290 0.034326 0.173169\nBq -0.984294 -0.034332 -0.173189\n","xyz");
# 	viewer_17330073937614915.setStyle({"sphere": {"radius": 0.3}, "stick": {"radius": 0.2}});
# 	viewer_17330073937614915.setStyle({"element": "C"},{"sphere": {"color": "black", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "H"},{"sphere": {"color": "white", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "O"},{"sphere": {"color": "red", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "N"},{"sphere": {"color": "blue", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "F"},{"sphere": {"color": "lime", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "Cl"},{"sphere": {"color": "green", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "Br"},{"sphere": {"color": "brown", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "I"},{"sphere": {"color": "purple", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "S"},{"sphere": {"color": "yellow", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "P"},{"sphere": {"color": "orange", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "B"},{"sphere": {"color": "pink", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"element": "R"},{"sphere": {"color": "grey", "radius": 0.3}});
# 	viewer_17330073937614915.setStyle({"elem": "Bq"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937614915.setStyle({"elem": "DA"},{"sphere": {"colorscheme": "element", "radius": 0.3}, "stick": {"hidden": true}});
# 	viewer_17330073937614915.zoomTo();
# viewer_17330073937614915.render();
# });
# </script>
# angle between: -1.744852626281978
# ring normal: [-0.98429194 -0.03432901 -0.17317877]
# angle between: -1.744852626281978
# ring normal: [-0.98429194 -0.03432901 -0.17317877]
# angle between: -1.744852626281978
# ring normal: [-0.98429194 -0.03432901 -0.17317877]
# for _benzene_x2_y2_z2, 0: -4.05030541006404
# angle between: -1.744852626281978
# ring normal: [-0.98429194 -0.03432901 -0.17317877]
# for _benzene_x2_y2_z2, 1: -4.0496302906794925
# all isotropic shifts: [-11.4973, -11.4972]
# all zz shifts: [-3.1887, -3.1886]
# all perp shifts: [np.float64(-4.05030541006404), np.float64(-4.0496302906794925)]
# ring averaged perp: [np.float64(-4.049967850371766)]

# %%
'/gpfs/research/alabuginlab/gage/michael/test/benzene/_benzene_x0_y0_z0/cam-b3ylp_6-31Gdp_NICS_gaussian_test' == '/gpfs/research/alabuginlab/gage/michael/test/benzene/_benzene_x0_y0_z0/cam-b3lyp_6-31Gdp_NICS_gaussian_test/cam-b3lyp_6-31Gdp_NICS_gaussian_test.log'
# Out:
# False
